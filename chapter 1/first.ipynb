# %% [markdown]
# how to create first program

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# <!-- my first code -->

# %%
import pyjokes
joke = pyjokes.get_joke()
print(joke)
# Out:
# There are 10 types of people: those who understand hexadecimal and 15 others.

# %%
import pyttsx3
engine = pyttsx3.init()

# For Mac, If you face error related to "pyobjc" when running the `init()` method :
# Install 9.0.1 version of pyobjc : "pip install pyobjc>=9.0.1"

engine.say("khadijaa pleease caaall to hasan and make tea for him")
engine.runAndWait()

# %%
import os
directory_path = '/'
contents = os.listdir(directory_path)
for item in contents :
    print (item)
# Out:
# $RECYCLE.BIN
# abc.ipynb
# abc.py
# abstract-paper-style-background.zip
# Adobe_Illustrator_2022_v26.0.1.731x64
# blue-abstract-background.zip
# Data
# Font
# Intel-Driver-and-Support-Assistant-Installer (1).exe
# python
# python course
# requrment.txt
# System Volume Information
# typescript
# Windows10Upgrade
